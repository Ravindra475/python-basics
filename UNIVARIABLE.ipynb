# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravindra475/python-basics/blob/master/UNIVARIABLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # for handling data in the form of tables
import numpy as np # For handling matrix
from sklearn.model_selection import train_test_split # For spliting the data into train and test
from sklearn.linear_model import LinearRegression # for using the model
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
rbs=pd.read_csv("students_placement_data.csv")
rbs.head()
# Out:
#    Roll No Gender  ... registered_for_ Placement_Training  placement status
# 0        1      M  ...                                 NO        Not placed
# 1        2      F  ...                                yes            Placed
# 2        3      F  ...                                yes        Not placed
# 3        4      M  ...                                yes        Not placed
# 4        5      M  ...                                yes        Not placed
#
# [5 rows x 9 columns]

# %%
slr.describe()
# Out:
#           Roll No  SSC Percentage  ...  B.Tech_percentage    Backlogs
# count  117.000000      117.000000  ...         117.000000  117.000000
# mean    59.000000       80.324359  ...          62.943419    4.111111
# std     33.919021        8.879266  ...          12.064306    6.335148
# min      1.000000       47.800000  ...          31.200000    0.000000
# 25%     30.000000       76.000000  ...          54.180000    0.000000
# 50%     59.000000       82.330000  ...          64.360000    0.000000
# 75%     88.000000       87.000000  ...          72.570000    7.000000
# max    117.000000       93.660000  ...          88.100000   25.000000
#
# [8 rows x 5 columns]

# %%
x=rbs['SSC Percentage'].values.reshape(-1,1)
x
y=rbs['inter_Diploma_percentage'].values.reshape(-1,1)
y
# Out:
# array([[65.3 ],
#        [92.4 ],
#        [68.  ],
#        [70.4 ],
#        [65.5 ],
#        [68.  ],
#        [56.5 ],
#        [79.3 ],
#        [89.6 ],
#        [75.5 ],
#        [76.3 ],
#        [66.  ],
#        [60.3 ],
#        [88.7 ],
#        [52.2 ],
#        [86.  ],
#        [85.  ],
#        [95.1 ],
#        [86.3 ],
#        [93.6 ],
#        [90.3 ],
#        [83.9 ],
#        [83.  ],
#        [90.4 ],
#        [87.2 ],
#        [78.3 ],
#        [81.  ],
#        [65.3 ],
#        [67.1 ],
#        [88.1 ],
#        [96.5 ],
#        [77.7 ],
#        [88.9 ],
#        [80.1 ],
#        [78.4 ],
#        [90.  ],
#        [91.4 ],
#        [94.3 ],
#        [76.8 ],
#        [88.8 ],
#        [91.4 ],
#        [61.2 ],
#        [67.5 ],
#        [92.5 ],
#        [83.7 ],
#        [84.4 ],
#        [76.9 ],
#        [89.1 ],
#        [77.2 ],
#        [93.8 ],
#        [92.2 ],
#        [79.  ],
#        [73.4 ],
#        [84.5 ],
#        [83.6 ],
# ...

# %%
 #Now divide the data into train and test. Here we are keeping 40% as our test set
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.5)

# %%
#Now apply linear regression model on training dataset
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(model.intercept_)  # This is our 'c'
# Out:
# [19.61675246]

# %%
print(model.coef_) # This is our 'm'
# Out:
# [[0.75108984]]

# %%
predicted_weight=model.predict(X_test) 
predicted_weight
# Out:
# array([[81.07843397],
#        [83.33921438],
#        [78.95284972],
#        [80.53013839],
#        [85.33711335],
#        [85.93798523],
#        [80.68035635],
#        [84.2104786 ],
#        [67.68650214],
#        [85.03667742],
#        [67.4311316 ],
#        [75.3175749 ],
#        [85.18689539],
#        [81.70183853],
#        [73.69522085],
#        [81.43144619],
#        [72.19304118],
#        [81.20611924],
#        [67.91182909],
#        [72.94413101],
#        [70.81103587],
#        [73.69522085],
#        [85.83283265],
#        [85.78776726],
#        [85.03667742],
#        [86.46374811],
#        [84.33065297],
#        [87.59038287],
#        [83.45938876],
#        [80.53013839],
#        [57.66696369],
#        [86.71160776],
#        [82.58061365],
#        [85.584973  ],
#        [75.19740053],
#        [82.07738345],
#        [89.96382676],
#        [85.83283265],
#        [81.20611924],
#        [79.62883058],
#        [74.07076577],
# ...

# %%
Actual_predicted=pd.DataFrame({'predicted':predicted_weight.flatten(), 'Actual':Y_test.flatten()})
Actual_predicted
# Out:
#     predicted  Actual
# 0   81.078434   83.70
# 1   83.339214   91.60
# 2   78.952850   79.00
# 3   80.530138   67.50
# 4   85.337113   84.40
# 5   85.937985   93.90
# 6   80.680356   85.12
# 7   84.210479   92.50
# 8   67.686502   56.70
# 9   85.036677   88.70
# 10  67.431132   69.00
# 11  75.317575   91.70
# 12  85.186895   65.30
# 13  81.701839   89.60
# 14  73.695221   81.00
# 15  81.431446   83.70
# 16  72.193041   81.00
# 17  81.206119   73.60
# 18  67.911829   67.10
# 19  72.944131   56.50
# 20  70.811036   62.60
# 21  73.695221   84.50
# 22  85.832833   91.40
# 23  85.787767   89.10
# 24  85.036677   81.00
# 25  86.463748   86.00
# 26  84.330653   87.20
# 27  87.590383   90.40
# 28  83.459389   89.60
# 29  80.530138   78.60
# 30  57.666964   54.20
# 31  86.711608   88.60
# 32  82.580614   90.30
# 33  85.584973   93.60
# 34  75.197401   76.80
# 35  82.077383   79.90
# 36  89.963827   95.10
# 37  85.832833   80.10
# 38  81.206119   91.40
# 39  79.628831   75.50
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(X_test,Y_test,color='red')
plt.plot(X_test,predicted_weight)

# %%
print('R2 error:',metrics.r2_score(Y_test, predicted_weight))
# Out:
# R2 error: 0.4720682560438857
